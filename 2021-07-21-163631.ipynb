# %%
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use(['seaborn-whitegrid', 'seaborn-poster'])

# %%
events_file = Path(r'athlete_events.csv')

# %%
events_file.exists()
# Out:
# True

# %%
Path('.').resolve()
# Out:
# WindowsPath('C:/Users/bnables/Documents/Python/meddle')

# %%
db = pd.read_csv(r'athlete_events.csv')

# %%
db
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %%
db['NOC'].unique()
# Out:
# array(['CHN', 'DEN', 'NED', 'USA', 'FIN', 'NOR', 'ROU', 'EST', 'FRA',
#        'MAR', 'ESP', 'EGY', 'IRI', 'BUL', 'ITA', 'CHA', 'AZE', 'SUD',
#        'RUS', 'ARG', 'CUB', 'BLR', 'GRE', 'CMR', 'TUR', 'CHI', 'MEX',
#        'URS', 'NCA', 'HUN', 'NGR', 'ALG', 'KUW', 'BRN', 'PAK', 'IRQ',
#        'UAR', 'LIB', 'QAT', 'MAS', 'GER', 'CAN', 'IRL', 'AUS', 'RSA',
#        'ERI', 'TAN', 'JOR', 'TUN', 'LBA', 'BEL', 'DJI', 'PLE', 'COM',
#        'KAZ', 'BRU', 'IND', 'KSA', 'SYR', 'MDV', 'ETH', 'UAE', 'YAR',
#        'INA', 'PHI', 'SGP', 'UZB', 'KGZ', 'TJK', 'EUN', 'JPN', 'CGO',
#        'SUI', 'BRA', 'FRG', 'GDR', 'MON', 'ISR', 'URU', 'SWE', 'ISV',
#        'SRI', 'ARM', 'CIV', 'KEN', 'BEN', 'UKR', 'GBR', 'GHA', 'SOM',
#        'LAT', 'NIG', 'MLI', 'AFG', 'POL', 'CRC', 'PAN', 'GEO', 'SLO',
#        'CRO', 'GUY', 'NZL', 'POR', 'PAR', 'ANG', 'VEN', 'COL', 'BAN',
#        'PER', 'ESA', 'PUR', 'UGA', 'HON', 'ECU', 'TKM', 'MRI', 'SEY',
#        'TCH', 'LUX', 'MTN', 'CZE', 'SKN', 'TTO', 'DOM', 'VIN', 'JAM',
#        'LBR', 'SUR', 'NEP', 'MGL', 'AUT', 'PLW', 'LTU', 'TOG', 'NAM',
#        'AHO', 'ISL', 'ASA', 'SAM', 'RWA', 'DMA', 'HAI', 'MLT', 'CYP',
#        'GUI', 'BIZ', 'YMD', 'KOR', 'THA', 'BER', 'ANZ', 'SCG', 'SLE',
#        'PNG', 'YEM', 'IOA', 'OMA', 'FIJ', 'VAN', 'MDA', 'YUG', 'BAH',
#        'GUA', 'SRB', 'IVB', 'MOZ', 'CAF', 'MAD', 'MAL', 'BIH', 'GUM',
#        'CAY', 'SVK', 'BAR', 'GBS', 'TLS', 'COD', 'GAB', 'SMR', 'LAO',
#        'BOT', 'ROT', 'CAM', 'PRK', 'SOL', 'SEN', 'CPV', 'CRT', 'GEQ',
#        'BOL', 'SAA', 'AND', 'ANT', 'ZIM', 'GRN', 'HKG', 'LCA', 'FSM',
#        'MYA', 'MAW', 'ZAM', 'RHO', 'TPE', 'STP', 'MKD', 'BOH', 'TGA',
#        'LIE', 'MNE', 'GAM', 'COK', 'ALB', 'WIF', 'SWZ', 'BUR', 'NBO',
#        'BDI', 'ARU', 'NRU', 'VNM', 'VIE', 'BHU', 'MHL', 'KIR', 'UNK',
#        'TUV', 'NFL', 'KOS', 'SSD', 'LES'], dtype=object)

# %%
len(db)
# Out:
# 271116

# %%
medals = db.dropna(subset=['Medal'])

# %%
medals
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
#                   Team  NOC        Games  Year  Season       City       Sport  \
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37             Finland  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 38             Finland  FIN  1920 Summer  1920  Summer  Antwerpen    Swimming
# 40             Finland  FIN  2014 Winter  2014  Winter      Sochi  Ice Hockey
# 41             Finland  FIN  1948 Summer  1948  Summer     London  Gymnastics
# ...                ...  ...          ...   ...     ...        ...         ...
# 271078    Soviet Union  URS  1956 Summer  1956  Summer  Melbourne   Athletics
# 271080    Soviet Union  URS  1964 Summer  1964  Summer      Tokyo   Athletics
# 271082          Poland  POL  1980 Summer  1980  Summer     Moskva     Fencing
# 271102          Russia  RUS  2000 Summer  2000  Summer     Sydney   Athletics
# 271103          Russia  RUS  2004 Summer  2004  Summer     Athina   Athletics
#
#                                          Event   Medal
# 3                  Tug-Of-War Men's Tug-Of-War    Gold
# 37      Swimming Men's 200 metres Breaststroke  Bronze
# 38      Swimming Men's 400 metres Breaststroke  Bronze
# 40                 Ice Hockey Men's Ice Hockey  Bronze
# 41      Gymnastics Men's Individual All-Around  Bronze
# ...                                        ...     ...
# 271078              Athletics Women's Shot Put  Silver
# 271080              Athletics Women's Shot Put  Bronze
# 271082                Fencing Men's Foil, Team  Bronze
# 271102  Athletics Women's 4 x 400 metres Relay  Bronze
# 271103  Athletics Women's 4 x 400 metres Relay  Silver
#
# [39783 rows x 15 columns]

# %%
len(medals)
# Out:
# 39783

# %%
len(medals) / len(db)
# Out:
# 0.14673792767671404

# %%
medal_counts = {}

# %%
medals[medals['Medal'] == 'Gold']
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
#                   Team  NOC        Games  Year  Season         City  \
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris
# 42             Finland  FIN  1948 Summer  1948  Summer       London
# 44             Finland  FIN  1948 Summer  1948  Summer       London
# 48             Finland  FIN  1948 Summer  1948  Summer       London
# 60              Norway  NOR  1992 Winter  1992  Winter  Albertville
# ...                ...  ...          ...   ...     ...          ...
# 270981         Georgia  GEO  2004 Summer  2004  Summer       Athina
# 271009         Germany  GER  2004 Summer  2004  Summer       Athina
# 271016     Netherlands  NED  1996 Summer  1996  Summer      Atlanta
# 271049     Netherlands  NED  1996 Summer  1996  Summer      Atlanta
# 271076    Soviet Union  URS  1952 Summer  1952  Summer     Helsinki
#
#                 Sport                             Event Medal
# 3          Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 42         Gymnastics  Gymnastics Men's Team All-Around  Gold
# 44         Gymnastics      Gymnastics Men's Horse Vault  Gold
# 48         Gymnastics  Gymnastics Men's Pommelled Horse  Gold
# 60      Alpine Skiing       Alpine Skiing Men's Super G  Gold
# ...               ...                               ...   ...
# 270981           Judo           Judo Men's Middleweight  Gold
# 271009         Hockey             Hockey Women's Hockey  Gold
# 271016     Volleyball       Volleyball Men's Volleyball  Gold
# 271049         Rowing         Rowing Men's Coxed Eights  Gold
# 271076      Athletics        Athletics Women's Shot Put  Gold
#
# [13372 rows x 15 columns]

# %%
medals[(medals['Medal'] == 'Gold') & (medals['NOC'] == 'USA') & (medals['Year'] == 2016) & (medals['Event'].str.contains("Men's Basketball"))]
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 8167      4505          Carmelo Kyan Anthony   M  32.0   203.0   109.0
# 14744     7956  Harrison Bryce Jordan Barnes   M  24.0   203.0   102.0
# 32900    16923              Jimmy Butler III   M  26.0   201.0    99.0
# 45521    23497         DeMarcus Amir Cousins   M  25.0   210.0   122.0
# 54075    27743         DeMar Darnell DeRozan   M  26.0   201.0    99.0
# 60168    30807            Kevin Wayne Durant   M  27.0   206.0   105.0
# 77908    39561                   Paul George   M  26.0   206.0    99.0
# 83874    42622          Draymond Jamal Green   M  26.0   200.0   104.0
# 103530   52383           Kyrie Andrew Irving   M  24.0   190.0    87.0
# 110505   55874    Hyland DeAndre Jordan, Jr.   M  28.0   211.0   120.0
# 143119   71822                    Kyle Lowry   M  30.0   183.0    93.0
# 239260  119932       Klay Alexander Thompson   M  26.0   200.0    97.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 8167    United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 14744   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 32900   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 45521   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 54075   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 60168   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 77908   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 83874   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 103530  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 110505  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 143119  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 239260  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
#
#              Sport                        Event Medal
# 8167    Basketball  Basketball Men's Basketball  Gold
# 14744   Basketball  Basketball Men's Basketball  Gold
# 32900   Basketball  Basketball Men's Basketball  Gold
# 45521   Basketball  Basketball Men's Basketball  Gold
# 54075   Basketball  Basketball Men's Basketball  Gold
# 60168   Basketball  Basketball Men's Basketball  Gold
# 77908   Basketball  Basketball Men's Basketball  Gold
# 83874   Basketball  Basketball Men's Basketball  Gold
# 103530  Basketball  Basketball Men's Basketball  Gold
# 110505  Basketball  Basketball Men's Basketball  Gold
# 143119  Basketball  Basketball Men's Basketball  Gold
# 239260  Basketball  Basketball Men's Basketball  Gold

# %%
mens_basketball_heights = db[(db['Sport'] == 'Basketball') & (db['Sex'] == 'M')]['Height'] / 2.54 / 12
mens_other_heights = db[(db['Sport'] != 'Basketball') & (db['Sex'] == 'M')]['Height'] / 2.54 / 12
mens_all_heights = db[(db['Sex'] == 'M')]['Height']/ 2.54 / 12

# %%
sns.histplot(mens_basketball_heights, label='Basketball', stat='count', color='orange')
sns.histplot(mens_other_heights, label='Not Basketball', stat='count')
sns.histplot(mens_all_heights, label='All', stat='count', color='gray')
plt.legend()

# %%
mens_basketball_heights = db[(db['Sport'] == 'Basketball') & (db['Sex'] == 'M') & (db['Year'] == 2016)]['Height'] / 2.54 / 12
mens_other_heights = db[(db['Sport'] != 'Basketball') & (db['Sex'] == 'M') & (db['Year'] == 2016)]['Height'] / 2.54 / 12
mens_all_heights = db[(db['Sex'] == 'M') & (db['Year'] == 2016)]['Height']/ 2.54 / 12

# %%
sns.histplot(mens_basketball_heights, label='Basketball', stat='count', color='orange')
sns.histplot(mens_other_heights, label='Not Basketball', stat='count', color='blue', alpha=0.5)
# sns.histplot(mens_all_heights, label='All', stat='count', color='gray')
plt.legend()

# %% [markdown]
# # Reduce by Event
#  - We want each row to be an Event Medal record, not an athlete - this collapses the teams

# %%
events = medals.drop_duplicates(['Year', 'Event', 'Sex', 'NOC'])
len(events)
# Out:
# 16883

# %%
events = medals.drop_duplicates(['Year', 'Event', 'Sex', 'NOC', 'Team', 'Games', 'Season', 'Sport', 'Medal'])
len(events)
# Out:
# 19166

# %%
events[(events['Year'] == 2016) & (events['Sport'].str.contains('Handball'))].sort_values('Medal')
# Out:
#           ID                         Name Sex   Age  Height  Weight     Team  \
# 5458    3077                   Ida Alstad   F  31.0   172.0    60.0   Norway
# 56128  28759          Christian Dissinger   M  24.0   203.0   105.0  Germany
# 23362  12290    Irina Valeryevna Bliznova   F  29.0   182.0    68.0   Russia
# 41295  21299            Mads Christiansen   M  30.0   197.0    93.0  Denmark
# 175       73                    Luc Abalo   M  31.0   182.0    86.0   France
# 11429   6241  Camille Anas Ayglon-Saurina   F  31.0   180.0    66.0   France
#
#        NOC        Games  Year  Season            City     Sport  \
# 5458   NOR  2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 56128  GER  2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 23362  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 41295  DEN  2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 175    FRA  2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 11429  FRA  2016 Summer  2016  Summer  Rio de Janeiro  Handball
#
#                            Event   Medal
# 5458   Handball Women's Handball  Bronze
# 56128    Handball Men's Handball  Bronze
# 23362  Handball Women's Handball    Gold
# 41295    Handball Men's Handball    Gold
# 175      Handball Men's Handball  Silver
# 11429  Handball Women's Handball  Silver

# %% [markdown]
# There have been hundreds of ties over the years. For example:

# %%
events[(events['Year'] == 2016) & (events['Event'].str.contains("Men's 100 metres Butterfly"))]
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 46722    24093             Lszl Cseh, Jr.   M  30.0   188.0    83.0
# 134053   67496  Chad Guy Bertrand le Clos   M  24.0   190.0    83.0
# 187913   94406    Michael Fred Phelps, II   M  31.0   193.0    91.0
# 213955  107436     Joseph Isaac Schooling   M  21.0   184.0    74.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 46722         Hungary  HUN  2016 Summer  2016  Summer  Rio de Janeiro
# 134053   South Africa  RSA  2016 Summer  2016  Summer  Rio de Janeiro
# 187913  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
#
United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
#
#             Sport                                 Event Medal
# 42626   Athletics    Athletics Men's 400 metres Hurdles  Gold
# 155042  Athletics    Athletics Men's 110 metres Hurdles  Gold
# 165085  Athletics  Athletics Women's 400 metres Hurdles  Gold
# 203515  Athletics  Athletics Women's 100 metres Hurdles  Gold

# %%
events[(events['Year'] == 2016) & (events['Event'].str.contains('Hurdle')) & (events['Sport'] == 'Athletics') & (events['Medal'] == 'Gold')]
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 42626    21990  Kerron Stephon Clement   M  30.0   188.0    86.0
# 155042   77819             Omar McLeod   M  22.0   180.0     NaN
# 165085   82900        Dalilah Muhammad   F  26.0   173.0    55.0
# 203515  102175         Brianna Rollins   F  24.0   165.0    59.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 42626   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 155042        Jamaica  JAM  2016 Summer  2016  Summer  Rio de Janeiro
# 165085  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 203515  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
#
#             Sport                                 Event Medal
# 42626   Athletics    Athletics Men's 400 metres Hurdles  Gold
# 155042  Athletics    Athletics Men's 110 metres Hurdles  Gold
# 165085  Athletics  Athletics Women's 400 metres Hurdles  Gold
# 203515  Athletics  Athletics Women's 100 metres Hurdles  Gold

# %%
events[(events['Year'] == 2016) & (events['Event'] == "Athletics Women's 100 metres Hurdles")]
# Out:
#             ID                Name Sex   Age  Height  Weight           Team  \
# 4727      2695  Nia Sifaatihii Ali   F  27.0   170.0    65.0  United States
# 36906    18976      Kristi Castlin   F  28.0   170.0    60.0  United States
# 203515  102175     Brianna Rollins   F  24.0   165.0    59.0  United States
#
#         NOC        Games  Year  Season            City      Sport  \
# 4727    USA  2016 Summer  2016  Summer  Rio de Janeiro  Athletics
# 36906   USA  2016 Summer  2016  Summer  Rio de Janeiro  Athletics
# 203515  USA  2016 Summer  2016  Summer  Rio de Janeiro  Athletics
#
#                                        Event   Medal
# 4727    Athletics Women's 100 metres Hurdles  Silver
# 36906   Athletics Women's 100 metres Hurdles  Bronze
# 203515  Athletics Women's 100 metres Hurdles    Gold

# %% [markdown]
# # Medal Count

# %% [markdown]
# Let's make some easy to use boolean mask variables

# %%
usa = events['NOC'] == 'USA'
y2016 = events['Year'] == 2016
y2012 = events['Year'] == 2012
gold = events['Medal'] == 'Gold'
silver = events['Medal'] == 'Silver'
bronze = events['Medal'] == 'Bronze'

# %% [markdown]
# All Gold Medals

# %%
len(events[gold])
# Out:
# 6283

# %% [markdown]
# All-time US Golds

# %%
len(events[usa & gold])
# Out:
# 1140

# %% [markdown]
# US Golds in 2016

# %%
len(events[usa & gold & y2016])
# Out:
# 47

# %%
countries = events['NOC'].unique()
countries
# Out:
# array(['DEN', 'FIN', 'NOR', 'NED', 'FRA', 'ITA', 'ESP', 'AZE', 'RUS',
#        'BLR', 'CMR', 'USA', 'HUN', 'GRE', 'AUS', 'IRI', 'CAN', 'PAK',
#        'URS', 'UZB', 'TJK', 'EUN', 'JPN', 'ETH', 'SUI', 'GDR', 'SWE',
#        'RSA', 'TUR', 'BUL', 'EGY', 'GBR', 'JOR', 'ROU', 'PUR', 'MEX',
#        'GHA', 'MAR', 'NZL', 'GER', 'ARG', 'CUB', 'URU', 'POL', 'TCH',
#        'NGR', 'BRA', 'AUT', 'LTU', 'INA', 'CHI', 'UKR', 'UGA', 'SYR',
#        'QAT', 'KUW', 'IOA', 'KSA', 'UAE', 'CRO', 'FRG', 'ARM', 'SRB',
#        'NIG', 'IND', 'BEL', 'ALG', 'JAM', 'TTO', 'COL', 'LUX', 'BOT',
#        'TUN', 'KOR', 'PRK', 'CHN', 'YUG', 'GUY', 'ISR', 'KAZ', 'GEO',
#        'KEN', 'ISL', 'HAI', 'MAS', 'IRQ', 'CZE', 'SVK', 'BAH', 'ANZ',
#        'PAR', 'MNE', 'IRL', 'POR', 'GUA', 'SCG', 'TAN', 'LIB', 'KGZ',
#        'LAT', 'AHO', 'VEN', 'THA', 'TOG', 'PER', 'EST', 'SLO', 'NEP',
#        'TPE', 'ZIM', 'MGL', 'MDA', 'CIV', 'FIJ', 'SEN', 'DOM', 'PHI',
#        'UAR', 'SGP', 'NAM', 'LIE', 'WIF', 'BOH', 'BER', 'VIE', 'ISV',
#        'MKD', 'SUD', 'BRN', 'GRN', 'SRI', 'MRI', 'KOS', 'HKG', 'CYP',
#        'PAN', 'ZAM', 'MON', 'MOZ', 'SUR', 'AFG', 'BDI', 'GAB', 'ECU',
#        'CRC', 'DJI', 'ERI', 'BAR', 'TGA'], dtype=object)

# %%
gold_counts = events[gold].groupby(['Year', 'Season', 'NOC'])['Medal'].count()
silver_counts = events[silver].groupby(['Year', 'Season', 'NOC'])['Medal'].count()
bronze_counts = events[bronze].groupby(['Year', 'Season', 'NOC'])['Medal'].count()

# %%
medal_types = db.Medal.dropna().unique()
counts_indexed = pd.DataFrame()
for name in medal_types:
    counts_indexed[name] = events[events.Medal == name].groupby(['Year', 'Season', 'NOC'])['Medal'].count()

# %%
counts_indexed
# Out:
#                  Gold  Bronze  Silver
# Year Season NOC
# 1896 Summer AUS     2     1.0     NaN
#             AUT     2     2.0     1.0
#             DEN     1     3.0     2.0
#             FRA     5     2.0     4.0
#             GBR     3     3.0     3.0
# ...               ...     ...     ...
# 2016 Summer TUR     1     4.0     3.0
#             UKR     2     4.0     5.0
#             USA    47    39.0    39.0
#             UZB     4     7.0     2.0
#             VIE     1     NaN     1.0
#
# [1112 rows x 3 columns]

# %%
gold_counts[2016, 'Summer', 'USA']
# Out:
# 47

# %%
counts_indexed.loc[2016, 'Summer', 'USA']
# Out:
# Gold      47.0
# Bronze    39.0
# Silver    39.0
# Name: (2016, Summer, USA), dtype: float64

# %%
counts = counts_indexed.reset_index()

# %%
counts
# Out:
#       Year  Season  NOC  Gold  Bronze  Silver
# 0     1896  Summer  AUS     2     1.0     NaN
# 1     1896  Summer  AUT     2     2.0     1.0
# 2     1896  Summer  DEN     1     3.0     2.0
# 3     1896  Summer  FRA     5     2.0     4.0
# 4     1896  Summer  GBR     3     3.0     3.0
# ...    ...     ...  ...   ...     ...     ...
# 1107  2016  Summer  TUR     1     4.0     3.0
# 1108  2016  Summer  UKR     2     4.0     5.0
# 1109  2016  Summer  USA    47    39.0    39.0
# 1110  2016  Summer  UZB     4     7.0     2.0
# 1111  2016  Summer  VIE     1     NaN     1.0
#
# [1112 rows x 6 columns]

# %%
counts[counts.Season=='Summer'].plot.scatter('Year', 'Gold')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Gold'>

# %%
# summer counts
sc = counts[counts.Season == 'Summer']

# %%
plt.plot(sc.Year+0.5, sc.Bronze, '.', alpha=0.5, label='Bronze', color='gray')
plt.plot(sc.Year, sc.Silver, '.', alpha=0.5, label='Silver', color='red')
plt.plot(sc.Year-0.5, sc.Gold, '.', alpha=0.5, label='Gold', color='blue')

plt.title('Medals Won by Countries vs. Year')
plt.ylabel('Medals Won')
plt.xlabel('Year')
plt.legend()

# %% [markdown]
# ## Calculating the number of each medal type earned per country and the most recent year of each win

# %%
import numpy as np

# %%
len(country_list)
# Out:
# 149

# %%
medals[medals['NOC'] == 'CHI']
# Out:
#             ID                                              Name Sex   Age  \
# 2584      1447            Marlene Ahrens Ostertag (-Ebensperger)   F  23.0
# 5562      3147                   Cristin Andrs lvarez Valenzuela   M  20.0
# 9714      5325                      Francisco Esteban Arru Pardo   M  23.0
# 15049     8118                          Claudio Barrientos Negrn   M  21.0
# 44229    22804                        Pablo Andrs Contreras Fica   M  22.0
# 46175    23833                                 scar Cristi Gallo   M  36.0
# 46176    23833                                 scar Cristi Gallo   M  36.0
# 50890    26177  Alfonso Marcos de Iruarrzaga Hoces de la Guardia   M  31.0
# 61112    31314                                 Ricardo Echeverra   M  34.0
# 81763    41512              Fernando Francisco Gonzlez Ciuffardi   M  24.0
# 81764    41512              Fernando Francisco Gonzlez Ciuffardi   M  24.0
# 81765    41512              Fernando Francisco Gonzlez Ciuffardi   M  28.0
# 82024    41649                    Sebastin Ignacio Gonzlez Valds   M  21.0
# 94296    47725                     David Andrs Henrquez Espinoza   M  23.0
# 101874   51518                    Manuel Francisco Ibarra Valdes   M  22.0
# 143425   71992                             Carlos Lucas Manrquez   M  26.0
# 147443   73998        Claudio Andrs del Trnsito Maldonado Rivera   M  20.0
# 151943   76256                       Nicols Alejandro Mass Fried   M  26.0
# 151944   76256                       Nicols Alejandro Mass Fried   M  26.0
# 156556   78643                        Csar Leonidas Mendoza Durn   M  33.0
# 168711   84793                   Reinaldo Marcelino Navia Amador   M  22.0
# 173885   87347                           Rodrigo Fabin Nez Ortiz   M  23.0
# 176200   88593                      Rafael Andrs Olarra Guerrero   M  22.0
# 178057   89477                       Luis Patricio Ormazbal Mozo   M  21.0
# 189719   95282                       David Marcelo Pizarro Corts   M  21.0
# 190002   95429                           Manuel Jess Plaza Reyes   M  28.0
# 199560  100228                       Pedro Antonio Reyes Gonzlez   M  27.0
# 203308  102084                        Mauricio Javier Rojas Toro   M  22.0
# 236417  118537                          Nelson Antonio Tapia Ros   M  33.0
# 236418  118538                                 Ramn Tapia Zapata   M  24.0
# 237486  119112                    Rodrigo lvaro Tello Valenzuela   M  20.0
# 267605  133880                          Ivn Luis Zamorano Zamora   M  33.0
#
#         Height  Weight   Team  NOC        Games  Year  Season       City  \
# 2584     176.0    70.0  Chile  CHI  1956 Summer  1956  Summer  Melbourne
# 5562     173.0    62.0  Chile  CHI  2000 Summer  2000  Summer     Sydney
# 9714     169.0    64.0  Chile  CHI  2000 Summer  2000  Summer     Sydney
# 15049      NaN     NaN  Chile  CHI  1956 Summer  1956  Summer  Melbourne
# 44229    180.0    77.0  Chile  CHI  2000 Summer  2000  Summer     Sydney
#
# Out:
# Medal    3
# dtype: int64

# %% [markdown]
# # This works?

# %%
column_list = ['Country','Gold','Silver','Bronze','Most Recent Gold Year','Most Recent Silver Year','Most Recent Bronze Year']
zero_data = np.zeros(shape = (len(country_list),len(column_list)))

medal_amount_df = pd.DataFrame(zero_data,columns = column_list)

newmedals = medals.sort_values('NOC', ascending = False).drop_duplicates(subset=['Year','Event','Medal'])

for i in range(len(country_list)):
    medal_amount_df.loc[i, 'Country'] = country_list[i]
    medal_amount_df['Gold'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][['Medal']].eq('Gold').sum()
    medal_amount_df['Silver'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][['Medal']].eq('Silver').sum()
    medal_amount_df['Bronze'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][['Medal']].eq('Bronze').sum()
    
    if len(newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Gold'].sort_values('Year', ascending = False)) != 0:
        medal_amount_df['Most Recent Gold Year'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Gold'].sort_values('Year', ascending = False)['Year'].iloc[0]
    else:
        medal_amount_df['Most Recent Gold Year'].iloc[i] = ''
        
    if len(newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Silver'].sort_values('Year', ascending = False)) != 0:
        medal_amount_df['Most Recent Silver Year'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Silver'].sort_values('Year', ascending = False)['Year'].iloc[0]
    else:
        medal_amount_df['Most Recent Silver Year'].iloc[i] = ''
        
    if len(newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Bronze'].sort_values('Year', ascending = False)) != 0:
        medal_amount_df['Most Recent Bronze Year'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Bronze'].sort_values('Year', ascending = False)['Year'].iloc[0]
    else:
        medal_amount_df['Most Recent Bronze Year'].iloc[i] = ''
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-51-d77f6c5fc8ad>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if len(newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Gold'].sort_values('Year', ascending = False)) != 0:
# <ipython-input-51-d77f6c5fc8ad>:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   medal_amount_df['Most Recent Gold Year'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Gold'].sort_values('Year', ascending = False)['Year'].iloc[0]
# <ipython-input-51-d77f6c5fc8ad>:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if len(newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Silver'].sort_values('Year', ascending = False)) != 0:
# <ipython-input-51-d77f6c5fc8ad>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   medal_amount_df['Most Recent Silver Year'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Silver'].sort_values('Year', ascending = False)['Year'].iloc[0]
# <ipython-input-51-d77f6c5fc8ad>:24: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if len(newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Bronze'].sort_values('Year', ascending = False)) != 0:
# <ipython-input-51-d77f6c5fc8ad>:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   medal_amount_df['Most Recent Bronze Year'].iloc[i] = newmedals[newmedals['NOC'] == country_list[i]][newmedals['Medal'] == 'Bronze'].sort_values('Year', ascending = False)['Year'].iloc[0]

# %%
medal_amount_df.sort_values('Gold', ascending = False)
# Out:
#     Country    Gold  Silver  Bronze Most Recent Gold Year  \
# 11      USA  1131.0   901.0   791.0                2016.0
# 18      URS   471.0   373.0   350.0                1988.0
# 39      GER   317.0   343.0   321.0                  2016
# 31      GBR   284.0   314.0   288.0                2016.0
# 4       FRA   258.0   275.0   289.0                2016.0
# ..      ...     ...     ...     ...                   ...
# 114     SEN     0.0     1.0     0.0
# 116     PHI     0.0     3.0     7.0
# 117     UAR     0.0     1.0     1.0
# 119     NAM     0.0     4.0     0.0
# 148     TGA     0.0     1.0     0.0
#
#     Most Recent Silver Year Most Recent Bronze Year
# 11                   2016.0                    2016
# 18                   1988.0                    1988
# 39                     2016                    2016
# 31                   2016.0                    2016
# 4                    2016.0                  2016.0
# ..                      ...                     ...
# 114                    1988
# 116                    2016                    1992
# 117                    1960                    1960
# 119                    1996
# 148                    1996
#
# [149 rows x 7 columns]

# %%
testdf = medals.sort_values('NOC', ascending = False).drop_duplicates(subset=['Year','Event','Medal'])

# %%
testdf
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 83484    42417  Ann-Mary Gwynne Grant (Fletcher-)   F  25.0   170.0    66.0
# 45645    23549    Kirsty Leigh Coventry (-Seward)   F  24.0   176.0    64.0
# 45647    23549    Kirsty Leigh Coventry (-Seward)   F  24.0   176.0    64.0
# 45646    23549    Kirsty Leigh Coventry (-Seward)   F  24.0   176.0    64.0
# 45641    23549    Kirsty Leigh Coventry (-Seward)   F  20.0   176.0    64.0
# ...        ...                                ...  ..   ...     ...     ...
# 156892   78805                 Nouria Mrah-Benida   F  29.0   162.0    54.0
# 89414    45314         Abderrahmane Hammad Zaheer   M  23.0   189.0    70.0
# 207879  104345             Assa Djabir Sad-Guerni   M  23.0   187.0    70.0
# 224926  112998                     Hocine Soltani   M  23.0   165.0    60.0
# 24200    12684                     Jan D. Boersma   M  19.0     NaN     NaN
#
#                         Team  NOC        Games  Year  Season     City  \
# 83484               Zimbabwe  ZIM  1980 Summer  1980  Summer   Moskva
# 45645               Zimbabwe  ZIM  2008 Summer  2008  Summer  Beijing
# 45647               Zimbabwe  ZIM  2008 Summer  2008  Summer  Beijing
# 45646               Zimbabwe  ZIM  2008 Summer  2008  Summer  Beijing
# 45641               Zimbabwe  ZIM  2004 Summer  2004  Summer   Athina
# ...                      ...  ...          ...   ...     ...      ...
# 156892               Algeria  ALG  2000 Summer  2000  Summer   Sydney
# 89414                Algeria  ALG  2000 Summer  2000  Summer   Sydney
# 207879               Algeria  ALG  2000 Summer  2000  Summer   Sydney
# 224926               Algeria  ALG  1996 Summer  1996  Summer  Atlanta
# 24200   Netherlands Antilles  AHO  1988 Summer  1988  Summer    Seoul
#
#             Sport                                          Event   Medal
# 83484      Hockey                          Hockey Women's Hockey    Gold
# 45645    Swimming         Swimming Women's 200 metres Backstroke    Gold
# 45647    Swimming  Swimming Women's 400 metres Individual Medley  Silver
# 45646    Swimming  Swimming Women's 200 metres Individual Medley  Silver
# 45641    Swimming         Swimming Women's 100 metres Backstroke  Silver
# ...           ...                                            ...     ...
# 156892  Athletics                 Athletics Women's 1,500 metres    Gold
# 89414   Athletics                      Athletics Men's High Jump  Bronze
# 207879  Athletics                     Athletics Men's 800 metres  Bronze
# 224926     Boxing                       Boxing Men's Lightweight    Gold
# 24200     Sailing                       Sailing Mixed Windsurfer  Silver
#
# [18293 rows x 15 columns]

# %%
testdf[testdf['NOC'] == 'USA'][['Medal']].eq('Gold').sum()
# Out:
# Medal    1131
# dtype: int64

# %%
testdf[testdf['Year'] == 2016][['Medal']].eq('Gold').sum()
# Out:
# Medal    306
# dtype: int64
